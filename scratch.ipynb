# %%
import pandas as pd

# %%
pd.read_parquet('outputs/intermediate/out10_to_20.parquet')
# Out:
#         tr2020ge  age_65_plus  age_under_65  total_population  \
# 0    53033000101          294          2432              2726
# 1    53033000102          380          3149              3529
# 2    53033000201          524          3244              3768
# 3    53033000202          540          3338              3878
# 4    53033000300          271          2332              2603
# ..           ...          ...           ...               ...
# 918  53061053803          501          4752              5253
# 919  53061940001          729          5733              6462
# 920  53061940002          595          3574              4169
# 921  53061990002            0             0                 0
# 922  53061990100            0             0                 0
#
#      above_200_percent_poverty  below_200_percent_poverty  \
# 0                         1758                        727
# 1                         2276                        940
# ...
